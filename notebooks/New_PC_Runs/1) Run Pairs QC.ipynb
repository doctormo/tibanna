# %%
from dcicutils import ff_utils
from core.utils import run_workflow
from core.wfr2 import *

my_env = 'data'
my_auth = ff_utils.get_authentication_with_server({}, ff_env = my_env)

add_wfr = True

# url for hic exps
pairs_url = "/search/?file_format=pairs&file_type=contact+list-replicate&file_type=contact+list-combined"+ \
            "&status=released&status=released+to+project&status=uploaded&type=FileProcessed" + \
            "&quality_metric.uuid=No+value&limit=all"
pairs_files = ff_utils.search_metadata(pairs_url , key=my_auth)
print len(pairs_files)

pairs_with_source = [i for i in pairs_files if i.get('source_experiments')]
print len(pairs_with_source)
# Out:
# 0
# 0

# %%
# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately


counter = 0
completed = 0
okay = 0
non = 0
running = 0
for a_pairs in pairs_files:

    # get experiment info
    exp_acc = a_pairs.get('source_experiments')
    if not exp_acc:
        print(a_pairs['accession'], 'does not have source experiments, skipping')
        continue

    #get enzyme and chrsize files
    nz_num, chrsize = extract_nz_file(exp_acc[0], my_auth)    
    if not nz_num:
        print nz_num, chrsize
        print(a_pairs['accession'], 'does not have RE/chrsize, skipping')
        continue
                         
    # get report
    report = get_wfr_out(a_pairs['accession'], 'pairsqc-single 0.2.5', my_auth, md_qc=True)
    
    # if report does not provide a complete or running run
    if report['status'].startswith('no'):
        non += 1
        if add_wfr:
            parameters = {"enzyme": nz_num,
                          "sample_name": a_pairs['accession']} 
            # if mouse, parameters get an additional parameter
            if chrsize == '4DNFI3UBJ3HZ':
                parameters['max_distance']= 8.2
            
            run_guide = {'wf_name': 'pairsqc-single',
                         'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3',
                         'parameters': parameters}
            
            print run_guide
            inp_f = {'input_pairs':a_pairs['accession'], 'chromsizes':chrsize} 
            print(a_pairs['accession'], 'starting the run')
            run_missing_wfr(run_guide, inp_f, a_pairs['accession'], my_env)
        else:
            print(a_pairs['accession'], 'needs a run')
    
    # if there is a completed or still running run
    elif report['status'] == 'running':
        running += 1
        print(a_pairs['accession'], 'still running')
    elif report['status'] == 'complete':
        okay += 1
    # if there is something funky
    else:
        print('report status is not covered, please check')
        break
    
        
print("okay, not okay, running")    
print(okay, non, running)
# Out:
# (u'4DNFICLCWWLH', 'still running')
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFI3Y5YTC6'}}
# (u'4DNFI3Y5YTC6', 'starting the run')
# about to start run pairsqc-single_4DNFI3Y5YTC6
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 57, 22, 502000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b6b31304-7645-11e8-adef-0d754c806cd9', 'HTTPHeaders': {'x-amzn-requestid': 'b6b31304-7645-11e8-adef-0d754c806cd9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI3Y5YTC6'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI3Y5YTC6
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIDHNCVEM'}}
# (u'4DNFIDHNCVEM', 'starting the run')
# about to start run pairsqc-single_4DNFIDHNCVEM
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 57, 35, 273000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'be50b00f-7645-11e8-b9b0-5bb63cda5bfc', 'HTTPHeaders': {'x-amzn-requestid': 'be50b00f-7645-11e8-b9b0-5bb63cda5bfc', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIDHNCVEM'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIDHNCVEM
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIW3YHQXS'}}
# (u'4DNFIW3YHQXS', 'starting the run')
# about to start run pairsqc-single_4DNFIW3YHQXS
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 57, 47, 616000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'c5abc627-7645-11e8-9cc4-a17476c89b8a', 'HTTPHeaders': {'x-amzn-requestid': 'c5abc627-7645-11e8-9cc4-a17476c89b8a', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIW3YHQXS'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIW3YHQXS
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIIUM9A7W'}}
# (u'4DNFIIUM9A7W', 'starting the run')
# about to start run pairsqc-single_4DNFIIUM9A7W
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 58, 0, 700000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'cd79747d-7645-11e8-a5f3-3d13d177d204', 'HTTPHeaders': {'x-amzn-requestid': 'cd79747d-7645-11e8-a5f3-3d13d177d204', 'content-length': '134', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIIUM9A7W'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIIUM9A7W
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIBDZ8KDQ'}}
# (u'4DNFIBDZ8KDQ', 'starting the run')
# about to start run pairsqc-single_4DNFIBDZ8KDQce2e36ab-4d6f-47b5-9c7a-ad6f3656de2c
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 58, 14, 392000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd5a08d28-7645-11e8-b894-2fcfecce3b8b', 'HTTPHeaders': {'x-amzn-requestid': 'd5a08d28-7645-11e8-b894-2fcfecce3b8b', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBDZ8KDQce2e36ab-4d6f-47b5-9c7a-ad6f3656de2c'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBDZ8KDQce2e36ab-4d6f-47b5-9c7a-ad6f3656de2c
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIYRP9RLI'}}
# (u'4DNFIYRP9RLI', 'starting the run')
# about to start run pairsqc-single_4DNFIYRP9RLI0eba4119-f80a-4c5a-b698-2a8f6555319c
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 58, 28, 98000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ddcbc55e-7645-11e8-9760-1b4c14500094', 'HTTPHeaders': {'x-amzn-requestid': 'ddcbc55e-7645-11e8-9760-1b4c14500094', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIYRP9RLI0eba4119-f80a-4c5a-b698-2a8f6555319c'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIYRP9RLI0eba4119-f80a-4c5a-b698-2a8f6555319c
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIKYF3V7I'}}
# (u'4DNFIKYF3V7I', 'starting the run')
# about to start run pairsqc-single_4DNFIKYF3V7If0a526f5-254a-4f1d-99d6-d9f647a75077
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 58, 41, 50000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e58527c9-7645-11e8-ab7e-7d64617277f6', 'HTTPHeaders': {'x-amzn-requestid': 'e58527c9-7645-11e8-ab7e-7d64617277f6', 'content-length': '171', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIKYF3V7If0a526f5-254a-4f1d-99d6-d9f647a75077'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIKYF3V7If0a526f5-254a-4f1d-99d6-d9f647a75077
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFI6S3I9XZ'}}
# (u'4DNFI6S3I9XZ', 'starting the run')
# about to start run pairsqc-single_4DNFI6S3I9XZf0864eab-debf-4db7-a558-c5ae214f6cf3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 58, 53, 558000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ecfa07a1-7645-11e8-beb7-07bb0dfa5949', 'HTTPHeaders': {'x-amzn-requestid': 'ecfa07a1-7645-11e8-beb7-07bb0dfa5949', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6S3I9XZf0864eab-debf-4db7-a558-c5ae214f6cf3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6S3I9XZf0864eab-debf-4db7-a558-c5ae214f6cf3
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIVPADLI2'}}
# (u'4DNFIVPADLI2', 'starting the run')
# about to start run pairsqc-single_4DNFIVPADLI265f31282-897b-485f-bce2-c6b1df193acb
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 59, 6, 70000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f46f360b-7645-11e8-a700-afd829596ef9', 'HTTPHeaders': {'x-amzn-requestid': 'f46f360b-7645-11e8-a700-afd829596ef9', 'content-length': '171', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIVPADLI265f31282-897b-485f-bce2-c6b1df193acb'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIVPADLI265f31282-897b-485f-bce2-c6b1df193acb
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIVMRIR5H'}}
# (u'4DNFIVMRIR5H', 'starting the run')
# about to start run pairsqc-single_4DNFIVMRIR5Hb1be1eb1-0c71-4ccd-971c-689dbb9fcbba
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 59, 20, 142000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'fcd18359-7645-11e8-9b35-57d499ed0057', 'HTTPHeaders': {'x-amzn-requestid': 'fcd18359-7645-11e8-9b35-57d499ed0057', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIVMRIR5Hb1be1eb1-0c71-4ccd-971c-689dbb9fcbba'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIVMRIR5Hb1be1eb1-0c71-4ccd-971c-689dbb9fcbba
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIUZJOJW9'}}
# (u'4DNFIUZJOJW9', 'starting the run')
# about to start run pairsqc-single_4DNFIUZJOJW9bc41cc3a-a045-4471-919e-bb2bc528a1b8
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 59, 33, 476000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '04c46c10-7646-11e8-9a7e-c39c9c48a22c', 'HTTPHeaders': {'x-amzn-requestid': '04c46c10-7646-11e8-9a7e-c39c9c48a22c', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIUZJOJW9bc41cc3a-a045-4471-919e-bb2bc528a1b8'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIUZJOJW9bc41cc3a-a045-4471-919e-bb2bc528a1b8
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIWRDI1OS'}}
# (u'4DNFIWRDI1OS', 'starting the run')
# about to start run pairsqc-single_4DNFIWRDI1OS
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 59, 45, 894000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '0c2acdeb-7646-11e8-ba28-3ff2fbfae0f3', 'HTTPHeaders': {'x-amzn-requestid': '0c2acdeb-7646-11e8-ba28-3ff2fbfae0f3', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIWRDI1OS'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIWRDI1OS
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIFCQQAGT'}}
# (u'4DNFIFCQQAGT', 'starting the run')
# about to start run pairsqc-single_4DNFIFCQQAGT
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 13, 59, 59, 287000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '14269107-7646-11e8-a60c-c70fd38654ab', 'HTTPHeaders': {'x-amzn-requestid': '14269107-7646-11e8-a60c-c70fd38654ab', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIFCQQAGT'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIFCQQAGT
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIC12SGRA'}}
# (u'4DNFIC12SGRA', 'starting the run')
# about to start run pairsqc-single_4DNFIC12SGRA
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 0, 12, 86000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '1bc89af1-7646-11e8-aa72-9522659982aa', 'HTTPHeaders': {'x-amzn-requestid': '1bc89af1-7646-11e8-aa72-9522659982aa', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIC12SGRA'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIC12SGRA
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI53L5LSY'}}
# (u'4DNFI53L5LSY', 'starting the run')
# about to start run pairsqc-single_4DNFI53L5LSY
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 0, 25, 161000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '2392a028-7646-11e8-beb7-07bb0dfa5949', 'HTTPHeaders': {'x-amzn-requestid': '2392a028-7646-11e8-beb7-07bb0dfa5949', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI53L5LSY'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI53L5LSY
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFILL56BEZ'}}
# (u'4DNFILL56BEZ', 'starting the run')
# about to start run pairsqc-single_4DNFILL56BEZ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 0, 37, 636000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '2b02c4e8-7646-11e8-b425-29c2cae895e4', 'HTTPHeaders': {'x-amzn-requestid': '2b02c4e8-7646-11e8-b425-29c2cae895e4', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILL56BEZ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILL56BEZ
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFI6IZYDDW'}}
# (u'4DNFI6IZYDDW', 'starting the run')
# about to start run pairsqc-single_4DNFI6IZYDDW
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 0, 50, 313000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '328f4b4e-7646-11e8-abf7-610a693dc5f9', 'HTTPHeaders': {'x-amzn-requestid': '328f4b4e-7646-11e8-abf7-610a693dc5f9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6IZYDDW'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6IZYDDW
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFICAV2SHE'}}
# (u'4DNFICAV2SHE', 'starting the run')
# about to start run pairsqc-single_4DNFICAV2SHE
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 1, 9, 957000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '3e47efcb-7646-11e8-a7ed-a15f8d39b0f9', 'HTTPHeaders': {'x-amzn-requestid': '3e47efcb-7646-11e8-a7ed-a15f8d39b0f9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICAV2SHE'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICAV2SHE
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFI2S641OK'}}
# (u'4DNFI2S641OK', 'starting the run')
# about to start run pairsqc-single_4DNFI2S641OK
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 1, 23, 953000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '469c80dd-7646-11e8-9b7d-a56b15912a3d', 'HTTPHeaders': {'x-amzn-requestid': '469c80dd-7646-11e8-9b7d-a56b15912a3d', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2S641OK'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2S641OK
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFI7BB4SOR'}}
# (u'4DNFI7BB4SOR', 'starting the run')
# about to start run pairsqc-single_4DNFI7BB4SOR
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 1, 36, 942000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4e5e6f09-7646-11e8-83cc-3f7e3de984e0', 'HTTPHeaders': {'x-amzn-requestid': '4e5e6f09-7646-11e8-83cc-3f7e3de984e0', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI7BB4SOR'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI7BB4SOR
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIOW2L46Z'}}
# (u'4DNFIOW2L46Z', 'starting the run')
# about to start run pairsqc-single_4DNFIOW2L46Z5533e2c9-7149-492f-8c84-bf3ca9f3519b
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 1, 49, 736000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '55fb9785-7646-11e8-9bcd-8d0258936eea', 'HTTPHeaders': {'x-amzn-requestid': '55fb9785-7646-11e8-9bcd-8d0258936eea', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIOW2L46Z5533e2c9-7149-492f-8c84-bf3ca9f3519b'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIOW2L46Z5533e2c9-7149-492f-8c84-bf3ca9f3519b
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIB5G24G6'}}
# (u'4DNFIB5G24G6', 'starting the run')
# about to start run pairsqc-single_4DNFIB5G24G6ea20a7e0-201b-4b90-a3ca-ad62f109dc81
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 2, 3, 103000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '5df55ec6-7646-11e8-9bcd-8d0258936eea', 'HTTPHeaders': {'x-amzn-requestid': '5df55ec6-7646-11e8-9bcd-8d0258936eea', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIB5G24G6ea20a7e0-201b-4b90-a3ca-ad62f109dc81'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIB5G24G6ea20a7e0-201b-4b90-a3ca-ad62f109dc81
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIHZIIVXC'}}
# (u'4DNFIHZIIVXC', 'starting the run')
# about to start run pairsqc-single_4DNFIHZIIVXC
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 2, 16, 764000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '66183195-7646-11e8-ad02-0903becd96b3', 'HTTPHeaders': {'x-amzn-requestid': '66183195-7646-11e8-ad02-0903becd96b3', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIHZIIVXC'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIHZIIVXC
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIXTMCDBY'}}
# (u'4DNFIXTMCDBY', 'starting the run')
# about to start run pairsqc-single_4DNFIXTMCDBY
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 2, 29, 829000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '6de17343-7646-11e8-bbec-6f3539f816b8', 'HTTPHeaders': {'x-amzn-requestid': '6de17343-7646-11e8-bbec-6f3539f816b8', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIXTMCDBY'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIXTMCDBY
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFI2S53S41'}}
# (u'4DNFI2S53S41', 'starting the run')
# about to start run pairsqc-single_4DNFI2S53S41
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 2, 43, 33000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '75be3d30-7646-11e8-a604-85773a6ca897', 'HTTPHeaders': {'x-amzn-requestid': '75be3d30-7646-11e8-a604-85773a6ca897', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2S53S41'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2S53S41
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIEJIO7TQ'}}
# (u'4DNFIEJIO7TQ', 'starting the run')
# about to start run pairsqc-single_4DNFIEJIO7TQ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 2, 55, 390000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '7d1de6db-7646-11e8-a7ed-a15f8d39b0f9', 'HTTPHeaders': {'x-amzn-requestid': '7d1de6db-7646-11e8-a7ed-a15f8d39b0f9', 'content-length': '135', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIEJIO7TQ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIEJIO7TQ
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIAIDD5SM'}}
# (u'4DNFIAIDD5SM', 'starting the run')
# about to start run pairsqc-single_4DNFIAIDD5SM
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 3, 9, 15000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '853d1138-7646-11e8-b254-95b9e363d249', 'HTTPHeaders': {'x-amzn-requestid': '853d1138-7646-11e8-b254-95b9e363d249', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIAIDD5SM'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIAIDD5SM
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFICUP7WGM'}}
# (u'4DNFICUP7WGM', 'starting the run')
# about to start run pairsqc-single_4DNFICUP7WGM
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 3, 22, 452000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8d3eee66-7646-11e8-9760-1b4c14500094', 'HTTPHeaders': {'x-amzn-requestid': '8d3eee66-7646-11e8-9760-1b4c14500094', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICUP7WGM'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICUP7WGM
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIRAHL9B5'}}
# (u'4DNFIRAHL9B5', 'starting the run')
# about to start run pairsqc-single_4DNFIRAHL9B5
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 3, 34, 906000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '94acf06e-7646-11e8-ab7e-7d64617277f6', 'HTTPHeaders': {'x-amzn-requestid': '94acf06e-7646-11e8-ab7e-7d64617277f6', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIRAHL9B5'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIRAHL9B5
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFI1KTTETW'}}
# (u'4DNFI1KTTETW', 'starting the run')
# about to start run pairsqc-single_4DNFI1KTTETW
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 3, 47, 407000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '9c1f5f41-7646-11e8-b894-2fcfecce3b8b', 'HTTPHeaders': {'x-amzn-requestid': '9c1f5f41-7646-11e8-b894-2fcfecce3b8b', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI1KTTETW'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI1KTTETW
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '6', 'sample_name': u'4DNFIOLCUOJ5'}}
# (u'4DNFIOLCUOJ5', 'starting the run')
# about to start run pairsqc-single_4DNFIOLCUOJ5
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 3, 59, 903000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a391322f-7646-11e8-9aa3-11de1893cdca', 'HTTPHeaders': {'x-amzn-requestid': 'a391322f-7646-11e8-9aa3-11de1893cdca', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIOLCUOJ5'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIOLCUOJ5
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFILXTX2FK'}}
# (u'4DNFILXTX2FK', 'starting the run')
# about to start run pairsqc-single_4DNFILXTX2FK
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 4, 13, 182000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ab78aa1a-7646-11e8-a604-85773a6ca897', 'HTTPHeaders': {'x-amzn-requestid': 'ab78aa1a-7646-11e8-a604-85773a6ca897', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILXTX2FK'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILXTX2FK
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIXB7BSRD'}}
# (u'4DNFIXB7BSRD', 'starting the run')
# about to start run pairsqc-single_4DNFIXB7BSRD
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 4, 26, 209000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b33ede6d-7646-11e8-8abf-1b6a79a54976', 'HTTPHeaders': {'x-amzn-requestid': 'b33ede6d-7646-11e8-8abf-1b6a79a54976', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIXB7BSRD'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIXB7BSRD
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI2ZOWMSI'}}
# (u'4DNFI2ZOWMSI', 'starting the run')
# about to start run pairsqc-single_4DNFI2ZOWMSI
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 4, 38, 398000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ba844971-7646-11e8-9060-1f907efa6ec2', 'HTTPHeaders': {'x-amzn-requestid': 'ba844971-7646-11e8-9060-1f907efa6ec2', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2ZOWMSI'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI2ZOWMSI
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIF4ROSFQ'}}
# (u'4DNFIF4ROSFQ', 'starting the run')
# about to start run pairsqc-single_4DNFIF4ROSFQ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 4, 51, 342000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'c23b6255-7646-11e8-9bcd-8d0258936eea', 'HTTPHeaders': {'x-amzn-requestid': 'c23b6255-7646-11e8-9bcd-8d0258936eea', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIF4ROSFQ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIF4ROSFQ
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIPD15L7F'}}
# (u'4DNFIPD15L7F', 'starting the run')
# about to start run pairsqc-single_4DNFIPD15L7F
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 5, 4, 515000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ca167e1a-7646-11e8-9b7d-a56b15912a3d', 'HTTPHeaders': {'x-amzn-requestid': 'ca167e1a-7646-11e8-9b7d-a56b15912a3d', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPD15L7F'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPD15L7F
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIPO3B1PB'}}
# (u'4DNFIPO3B1PB', 'starting the run')
# about to start run pairsqc-single_4DNFIPO3B1PB
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 5, 18, 498000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd269af99-7646-11e8-bac8-a970ea9dc0c2', 'HTTPHeaders': {'x-amzn-requestid': 'd269af99-7646-11e8-bac8-a970ea9dc0c2', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPO3B1PB'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPO3B1PB
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFILGYM2LC'}}
# (u'4DNFILGYM2LC', 'starting the run')
# about to start run pairsqc-single_4DNFILGYM2LC
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 5, 31, 63000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd9e59539-7646-11e8-b491-2f3376fa9966', 'HTTPHeaders': {'x-amzn-requestid': 'd9e59539-7646-11e8-b491-2f3376fa9966', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILGYM2LC'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILGYM2LC
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIP14P3DA'}}
# (u'4DNFIP14P3DA', 'starting the run')
# about to start run pairsqc-single_4DNFIP14P3DA
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 5, 43, 945000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e1931118-7646-11e8-8273-63690d5b5c39', 'HTTPHeaders': {'x-amzn-requestid': 'e1931118-7646-11e8-8273-63690d5b5c39', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIP14P3DA'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIP14P3DA
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIER3LJY8'}}
# (u'4DNFIER3LJY8', 'starting the run')
# about to start run pairsqc-single_4DNFIER3LJY8
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 5, 57, 101000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e96d69a5-7646-11e8-bbe2-d761240100b9', 'HTTPHeaders': {'x-amzn-requestid': 'e96d69a5-7646-11e8-bbe2-d761240100b9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIER3LJY8'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIER3LJY8
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIY3CIM91'}}
# (u'4DNFIY3CIM91', 'starting the run')
# about to start run pairsqc-single_4DNFIY3CIM91
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 6, 9, 367000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f0baeb1d-7646-11e8-bbe2-d761240100b9', 'HTTPHeaders': {'x-amzn-requestid': 'f0baeb1d-7646-11e8-bbe2-d761240100b9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIY3CIM91'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIY3CIM91
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIHBGHFJW'}}
# (u'4DNFIHBGHFJW', 'starting the run')
# about to start run pairsqc-single_4DNFIHBGHFJW
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 6, 21, 695000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f815b339-7646-11e8-81eb-bf81e689bc63', 'HTTPHeaders': {'x-amzn-requestid': 'f815b339-7646-11e8-81eb-bf81e689bc63', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIHBGHFJW'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIHBGHFJW
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFILYZ9YSA'}}
# (u'4DNFILYZ9YSA', 'starting the run')
# about to start run pairsqc-single_4DNFILYZ9YSA
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 6, 34, 390000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ffa6800e-7646-11e8-81eb-bf81e689bc63', 'HTTPHeaders': {'x-amzn-requestid': 'ffa6800e-7646-11e8-81eb-bf81e689bc63', 'content-length': '135', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILYZ9YSA'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFILYZ9YSA
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI1I3NFHG'}}
# (u'4DNFI1I3NFHG', 'starting the run')
# about to start run pairsqc-single_4DNFI1I3NFHG
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 6, 46, 863000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '07148137-7647-11e8-8066-9718adbb6f10', 'HTTPHeaders': {'x-amzn-requestid': '07148137-7647-11e8-8066-9718adbb6f10', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI1I3NFHG'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI1I3NFHG
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIV57K7CS'}}
# (u'4DNFIV57K7CS', 'starting the run')
# about to start run pairsqc-single_4DNFIV57K7CS
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 6, 59, 394000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '0e8f7bed-7647-11e8-b9c1-ed2aba2ecccc', 'HTTPHeaders': {'x-amzn-requestid': '0e8f7bed-7647-11e8-b9c1-ed2aba2ecccc', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIV57K7CS'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIV57K7CS
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIPZK844C'}}
# (u'4DNFIPZK844C', 'starting the run')
# about to start run pairsqc-single_4DNFIPZK844C
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 7, 11, 784000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '15f28126-7647-11e8-b88f-8158852aa3cf', 'HTTPHeaders': {'x-amzn-requestid': '15f28126-7647-11e8-b88f-8158852aa3cf', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPZK844C'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPZK844C
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIO2FMSL3'}}
# (u'4DNFIO2FMSL3', 'starting the run')
# about to start run pairsqc-single_4DNFIO2FMSL3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 7, 24, 82000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '1d44be6b-7647-11e8-ae88-d5c53e7e1874', 'HTTPHeaders': {'x-amzn-requestid': '1d44be6b-7647-11e8-ae88-d5c53e7e1874', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIO2FMSL3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIO2FMSL3
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI6ZBWB81'}}
# (u'4DNFI6ZBWB81', 'starting the run')
# about to start run pairsqc-single_4DNFI6ZBWB81
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 7, 36, 380000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '249a2f9c-7647-11e8-83cc-3f7e3de984e0', 'HTTPHeaders': {'x-amzn-requestid': '249a2f9c-7647-11e8-83cc-3f7e3de984e0', 'content-length': '135', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6ZBWB81'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI6ZBWB81
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI85DU7IM'}}
# (u'4DNFI85DU7IM', 'starting the run')
# about to start run pairsqc-single_4DNFI85DU7IM
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 7, 49, 500000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '2c6b600c-7647-11e8-81d5-e9231a06af1d', 'HTTPHeaders': {'x-amzn-requestid': '2c6b600c-7647-11e8-81d5-e9231a06af1d', 'content-length': '134', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI85DU7IM'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI85DU7IM
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFID618BP5'}}
# (u'4DNFID618BP5', 'starting the run')
# about to start run pairsqc-single_4DNFID618BP5defbf000-a1ef-48a3-b8ad-94386eb79bdc
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 8, 3, 859000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '34fa62bb-7647-11e8-ad91-ab3ae94910cc', 'HTTPHeaders': {'x-amzn-requestid': '34fa62bb-7647-11e8-ad91-ab3ae94910cc', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFID618BP5defbf000-a1ef-48a3-b8ad-94386eb79bdc'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFID618BP5defbf000-a1ef-48a3-b8ad-94386eb79bdc
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIREZHHOV'}}
# (u'4DNFIREZHHOV', 'starting the run')
# about to start run pairsqc-single_4DNFIREZHHOV8b7f0082-41c4-4172-98b3-c05911c428c5
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 8, 16, 842000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '3cb8ce5e-7647-11e8-ab7e-7d64617277f6', 'HTTPHeaders': {'x-amzn-requestid': '3cb8ce5e-7647-11e8-ab7e-7d64617277f6', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIREZHHOV8b7f0082-41c4-4172-98b3-c05911c428c5'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIREZHHOV8b7f0082-41c4-4172-98b3-c05911c428c5
# ...
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 16, 1, 857000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '51e4019e-7648-11e8-9b35-57d499ed0057', 'HTTPHeaders': {'x-amzn-requestid': '51e4019e-7648-11e8-9b35-57d499ed0057', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIDFRSE2Gf431a450-fabc-453e-94aa-7c61643ce85b'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIDFRSE2Gf431a450-fabc-453e-94aa-7c61643ce85b
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFI4PDERVK'}}
# (u'4DNFI4PDERVK', 'starting the run')
# about to start run pairsqc-single_4DNFI4PDERVKcdae3f54-1276-4ee4-a6c5-446c519cda7c
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 16, 14, 290000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '594d492f-7648-11e8-9def-27515c3041e1', 'HTTPHeaders': {'x-amzn-requestid': '594d492f-7648-11e8-9def-27515c3041e1', 'content-length': '171', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI4PDERVKcdae3f54-1276-4ee4-a6c5-446c519cda7c'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI4PDERVKcdae3f54-1276-4ee4-a6c5-446c519cda7c
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIEIEFZMD'}}
# (u'4DNFIEIEFZMD', 'starting the run')
# about to start run pairsqc-single_4DNFIEIEFZMD41a3d345-73a7-4203-99a7-8c9522089101
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 16, 27, 221000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '61023ee0-7648-11e8-aa72-41a3ca92f1ff', 'HTTPHeaders': {'x-amzn-requestid': '61023ee0-7648-11e8-aa72-41a3ca92f1ff', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIEIEFZMD41a3d345-73a7-4203-99a7-8c9522089101'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIEIEFZMD41a3d345-73a7-4203-99a7-8c9522089101
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFICY5CI8Q'}}
# (u'4DNFICY5CI8Q', 'starting the run')
# about to start run pairsqc-single_4DNFICY5CI8Qc9a3d66d-1ec9-43bd-99b1-34bdb601bbe3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 16, 39, 967000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '689b2165-7648-11e8-a003-9b7ec92d67b2', 'HTTPHeaders': {'x-amzn-requestid': '689b2165-7648-11e8-a003-9b7ec92d67b2', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICY5CI8Qc9a3d66d-1ec9-43bd-99b1-34bdb601bbe3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICY5CI8Qc9a3d66d-1ec9-43bd-99b1-34bdb601bbe3
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFI3CBEV3I'}}
# (u'4DNFI3CBEV3I', 'starting the run')
# about to start run pairsqc-single_4DNFI3CBEV3I882bf341-65bc-46ad-a89a-ff3b45b06cce
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 16, 52, 445000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '700998ae-7648-11e8-815b-cd727aa84da0', 'HTTPHeaders': {'x-amzn-requestid': '700998ae-7648-11e8-815b-cd727aa84da0', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI3CBEV3I882bf341-65bc-46ad-a89a-ff3b45b06cce'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI3CBEV3I882bf341-65bc-46ad-a89a-ff3b45b06cce
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIC2O325X'}}
# (u'4DNFIC2O325X', 'starting the run')
# about to start run pairsqc-single_4DNFIC2O325X60cbab49-1e34-4bbc-8bb0-b924a3777b5e
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 17, 5, 425000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '77c71ac6-7648-11e8-941f-ffb3b3738ca4', 'HTTPHeaders': {'x-amzn-requestid': '77c71ac6-7648-11e8-941f-ffb3b3738ca4', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIC2O325X60cbab49-1e34-4bbc-8bb0-b924a3777b5e'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIC2O325X60cbab49-1e34-4bbc-8bb0-b924a3777b5e
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'max_distance': 8.2, 'enzyme': '4', 'sample_name': u'4DNFIPWEWCY3'}}
# (u'4DNFIPWEWCY3', 'starting the run')
# about to start run pairsqc-single_4DNFIPWEWCY398f9551e-0e47-412e-8721-373a68d8b80d
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 17, 18, 205000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '7f66b3ac-7648-11e8-a6c2-9b0310f4a36b', 'HTTPHeaders': {'x-amzn-requestid': '7f66b3ac-7648-11e8-a6c2-9b0310f4a36b', 'content-length': '172', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPWEWCY398f9551e-0e47-412e-8721-373a68d8b80d'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIPWEWCY398f9551e-0e47-412e-8721-373a68d8b80d
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFING6ZFDF'}}
# (u'4DNFING6ZFDF', 'starting the run')
# about to start run pairsqc-single_4DNFING6ZFDF
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 17, 30, 723000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '86bd0ecc-7648-11e8-a003-9b7ec92d67b2', 'HTTPHeaders': {'x-amzn-requestid': '86bd0ecc-7648-11e8-a003-9b7ec92d67b2', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFING6ZFDF'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFING6ZFDF
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIMT4PHZ1'}}
# (u'4DNFIMT4PHZ1', 'starting the run')
# about to start run pairsqc-single_4DNFIMT4PHZ1
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 17, 43, 30000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8e31532c-7648-11e8-ba52-3343a5024926', 'HTTPHeaders': {'x-amzn-requestid': '8e31532c-7648-11e8-ba52-3343a5024926', 'content-length': '135', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIMT4PHZ1'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIMT4PHZ1
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIBMG8YA3'}}
# (u'4DNFIBMG8YA3', 'starting the run')
# about to start run pairsqc-single_4DNFIBMG8YA3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 17, 55, 250000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '9579cb2b-7648-11e8-899e-5175d8e00f3c', 'HTTPHeaders': {'x-amzn-requestid': '9579cb2b-7648-11e8-899e-5175d8e00f3c', 'content-length': '135', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBMG8YA3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBMG8YA3
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFI8GM4EL9'}}
# (u'4DNFI8GM4EL9', 'starting the run')
# about to start run pairsqc-single_4DNFI8GM4EL9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 18, 7, 484000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '9cc52a6d-7648-11e8-aa72-9522659982aa', 'HTTPHeaders': {'x-amzn-requestid': '9cc52a6d-7648-11e8-aa72-9522659982aa', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI8GM4EL9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFI8GM4EL9
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIBHI5YI9'}}
# (u'4DNFIBHI5YI9', 'starting the run')
# about to start run pairsqc-single_4DNFIBHI5YI9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 18, 20, 62000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a4437fda-7648-11e8-91dc-4512c813de3b', 'HTTPHeaders': {'x-amzn-requestid': 'a4437fda-7648-11e8-91dc-4512c813de3b', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBHI5YI9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIBHI5YI9
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIJZDEIZ3'}}
# (u'4DNFIJZDEIZ3', 'starting the run')
# about to start run pairsqc-single_4DNFIJZDEIZ3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 18, 32, 219000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ab8409c0-7648-11e8-9197-d9f16c0f7dde', 'HTTPHeaders': {'x-amzn-requestid': 'ab8409c0-7648-11e8-9197-d9f16c0f7dde', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIJZDEIZ3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIJZDEIZ3
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFICOEXGPJ'}}
# (u'4DNFICOEXGPJ', 'starting the run')
# about to start run pairsqc-single_4DNFICOEXGPJ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 18, 44, 573000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b2e0589d-7648-11e8-a7fd-c5241f245b31', 'HTTPHeaders': {'x-amzn-requestid': 'b2e0589d-7648-11e8-a7fd-c5241f245b31', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICOEXGPJ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFICOEXGPJ
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIN7IIIY6'}}
# (u'4DNFIN7IIIY6', 'starting the run')
# about to start run pairsqc-single_4DNFIN7IIIY6
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 18, 56, 798000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ba2a0980-7648-11e8-9060-1f907efa6ec2', 'HTTPHeaders': {'x-amzn-requestid': 'ba2a0980-7648-11e8-9060-1f907efa6ec2', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIN7IIIY6'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIN7IIIY6
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIYBTHGNA'}}
# (u'4DNFIYBTHGNA', 'starting the run')
# about to start run pairsqc-single_4DNFIYBTHGNA
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 19, 10, 58000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'c211a8de-7648-11e8-a700-afd829596ef9', 'HTTPHeaders': {'x-amzn-requestid': 'c211a8de-7648-11e8-a700-afd829596ef9', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIYBTHGNA'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIYBTHGNA
# {'wf_uuid': 'b8c533e0-f8c0-4510-b4a1-ac35158e27c3', 'wf_name': 'pairsqc-single', 'parameters': {'enzyme': '6', 'sample_name': u'4DNFIK8UIB5B'}}
# (u'4DNFIK8UIB5B', 'starting the run')
# about to start run pairsqc-single_4DNFIK8UIB5B
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 6, 22, 14, 19, 22, 304000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'c95b8033-7648-11e8-9655-6b19998162b5', 'HTTPHeaders': {'x-amzn-requestid': 'c95b8033-7648-11e8-9655-6b19998162b5', 'content-length': '136', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIK8UIB5B'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:pairsqc-single_4DNFIK8UIB5B
# okay, not okay, running
# (0, 103, 1)

# %%
# Release pairs qc
pairs_url = '/search/?file_format=pairs&status=released&status=released%20to%20project&status=uploaded&type=FileProcessed&limit=all'
pairs_files = ff_utils.search_metadata(pairs_url , key=my_auth)
pairs_files = [i for i in pairs_files if i.get('quality_metric')]
print len(pairs_files)

patch = True
need_patch = 0
for pairs in pairs_files:
    pairs_status = pairs['status']
    if pairs_status in ['released', 'released to project']:
        qc_uuid = pairs['quality_metric']['uuid']
        qc_status = ff_utils.get_metadata(qc_uuid,key=my_auth)['status']
        if qc_status != pairs_status:
            need_patch += 1
            patch_data = {"status": pairs_status}
            if patch:
                ff_utils.patch_metadata(patch_data, obj_id=qc_uuid ,key=my_auth)
print need_patch
# Out:
# 447
# 68

# %%
# Release qc reports, or assocuate labs with qc reports
# Add more text to functions in importdata and get fields info.
