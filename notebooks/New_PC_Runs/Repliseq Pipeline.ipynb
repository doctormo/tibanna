# %%
from dcicutils import ff_utils
import time
from core.wfr2 import *
from core.wfr_settings import *

# tibanna = Tibanna(env=env)
my_env = 'data'
my_auth = ff_utils.get_authentication_with_server({}, ff_env = my_env)

# %%
# url for repliseq exps
exp_types = ['Repli-seq']
set_url = '/search/?'+'&'.join(['experiments_in_set.experiment_type='+i for i in exp_types])+ \
          '&type=ExperimentSetReplicate&limit=all'
run_sets = ff_utils.search_metadata(set_url ,key=my_auth)

add_pc = True
add_rel = False
add_wfr = False

counter = 0
completed = 0
completed_acc = []
all_sets = len(run_sets)
print(str(all_sets)+' total number of sets')

run_sets = [i for i in run_sets if "RepliSeq_Pipeline_0.2.5"  not in i.get('completed_processes', [])]

print(str(all_sets-len(run_sets))+ ' sets completed')


for a_set in run_sets: 
    counter += 1
    print
    fastqpairs, organism, enzyme, bwa_ref, chrsize_ref, enz_ref, f_size, lab = find_pairs(a_set, my_env, lookfor = 'single')
    if not bwa_ref or not chrsize_ref:
        print counter, a_set['accession'], organism, enzyme, 'skipping set with not chrsize/bwa index'
        continue  
    print counter, a_set['accession'], enzyme, organism      
    # cycle through the experiments
    for exp in fastqpairs.keys():
        if not fastqpairs.get(exp):
            print(exp, 'does not have any fastq files')
            continue
        # Check Part 1 and See if all are okay
        exp_bams = []
        part1 = 'done'
        # part2 = 'done'
        for pair in fastqpairs[exp]:
            #############
            report = get_wfr_out(pair, 'repliseq-parta 0.2.5', my_auth)
            # if run is not successful
            if report['status'].startswith('no'):
                part1 = 'not done'
                if add_wfr:
                    inp_f = {'fastq':pair, 'chromsizes':chrsize_ref, 'bwaIndex':bwa_ref}
                    name_tag = pair.split('/')[2]
                    run_missing_wfr(step_settings('repliseq-parta', organism, lab), inp_f, name_tag, env)
            elif report['status'] == 'running':
                part1 = 'still running'
                print('part1 still running')
            # if successful
            else:
                assert report['status'] == 'complete'
                if add_pc:
                    add_preliminary_processed_files(exp,
                                                    [report['bam'], report['bg']],
                                                    my_auth,
                                                    run_type='repliseq')
        # stop progress to part2 
        if part1 is not 'done':
            print exp, 'has missing Part1 runs'
            part2 = 'not ready'
            part3 = 'not ready'
            continue
        print exp, 'part1 complete'
# Out:
# 41 total number of sets
# 0 sets completed
#
# 1 4DNESUZ3Y5GY None human
# 4DNEXE23WWO1 part1 complete
# 4DNEXG6HJJ27 part1 complete
#
# 2 4DNESIV168N6 None human
# 4DNEXVRTS3VG part1 complete
# 4DNEXELBLZ37 part1 complete
#
# 3 4DNESXZ2IL4M None human
# 4DNEXKP295JF part1 complete
#
# 4 4DNESJOH66ZZ None human
# 4DNEXYX58PCM part1 complete
#
# 5 4DNESQ3ZDLZM None human
# 4DNEXCTB91SG part1 complete
#
# 6 4DNES98TS7X2 None human
# 4DNEXXIXTTXI part1 complete
#
# 7 4DNESX6MGDN2 None human
# 4DNEXLVWLA33 part1 complete
#
# 8 4DNES6O1SJ4O None human
# 4DNEX1BWBWFA part1 complete
#
# 9 4DNESWS6UT74 None human
# 4DNEXZPBA82F part1 complete
#
# 10 4DNESBAF7EW5 None human
# 4DNEXDWEK1ME part1 complete
#
# 11 4DNES9OZNM6T None human
# 4DNEXTM3PBS3 part1 complete
#
# 12 4DNESDFQDLQJ None human
# 4DNEX8K5TT7Y part1 complete
#
# 13 4DNES3DSRT51 None human
# 4DNEXS77PTUK part1 complete
#
# 14 4DNES7OJ7U7X None human
# 4DNEXQ4EXW3K part1 complete
#
# 15 4DNESLS88OS7 None human
# 4DNEXEQB7RNA part1 complete
#
# 16 4DNESDUJHQ6J None human
# 4DNEX5M9XSGK part1 complete
#
# 17 4DNESCBR4664 None human
# 4DNEXKCP8338 part1 complete
#
# 18 4DNESJNUUJ66 None human
# 4DNEXL6WTINA part1 complete
#
# 19 4DNES5PW6NSG None human
# 4DNEXDRZLEQV part1 complete
#
# 20 4DNESSV33VOL None human
# 4DNEX63QU5GZ part1 complete
# 4DNEXTG6XPXD part1 complete
#
# 21 4DNESH4XLJCW None human
# 4DNEXR87VFPR part1 complete
# 4DNEXRK56264 part1 complete
#
# 22 4DNES99LXRYK None human
# 4DNEXWNB33S2 part1 complete
# 4DNEX25G1FKX part1 complete
#
# 23 4DNES1P18J2X None human
# 4DNEXAM4T83J part1 complete
# 4DNEXBL1Y5N4 part1 complete
#
# 24 4DNESLC8TDK4 None human
# 4DNEX6SUB7CY part1 complete
# 4DNEXAPQBU2M part1 complete
#
# 25 4DNESSYKYIK3 None human
# 4DNEXLRK3X6D part1 complete
# 4DNEXVQ9XCJ5 part1 complete
#
# 26 4DNES1GSPUT8 None human
# 4DNEXPCVJ25I part1 complete
# 4DNEXKWN7CZT part1 complete
#
# 27 4DNES9YA22WT None human
# 4DNEXBCDJFX9 part1 complete
# 4DNEXXZUM1J1 part1 complete
#
# 28 4DNES1PHNYOP None mouse
# 4DNEX14L7KXP part1 complete
# 4DNEXTTY1KTG part1 complete
#
# 29 4DNESWPIPVZT None mouse
# 4DNEX91MUU81 part1 complete
# 4DNEXWTU45NI part1 complete
#
# 30 4DNEST651P8O None human
# 4DNEXK7XIMBW part1 complete
# 4DNEXB7RB9KT part1 complete
#
# 31 4DNESJQH3HJ9 None human
# 4DNEXUFNTG8J part1 complete
# 4DNEX9GKA2OI part1 complete
#
# 32 4DNES674QWXK None human
# 4DNEX9CR3FWQ part1 complete
# 4DNEXCDJJVUR part1 complete
#
# 33 4DNESUNOW1OZ None human
# 4DNEX1HYSKMF part1 complete
# 4DNEXMFJRLJN part1 complete
#
# 34 4DNESJPG5AS9 None human
# 4DNEXZLZZO9L part1 complete
# 4DNEXHV4R6RJ part1 complete
#
# 35 4DNESCOUGP8R None human
# 4DNEX61WVI1Y part1 complete
# 4DNEXY72J4DD part1 complete
#
# 36 4DNES4CEYDPH None human
# 4DNEXGRP461A part1 complete
# 4DNEX8I12H9D part1 complete
#
# 37 4DNES8128EIS None human
# 4DNEXMHCH1TT part1 complete
# 4DNEXJFQRJ38 part1 complete
#
# 38 4DNESUJC9Y83 None human
# 4DNEXN62FHTX part1 complete
# 4DNEXSA3QR2O part1 complete
#
# 39 4DNES4B7RLAV None human
# 4DNEX6GMB44Z part1 complete
# 4DNEXWR7XY8S part1 complete
#
# 40 4DNESDQ9PZOX None human
# 4DNEXFBHF2ZI part1 complete
# 4DNEXGZEOJE6 part1 complete
#
# 41 4DNESO83H9ZI None human
# 4DNEXF2KKZF1 part1 complete
# 4DNEXI55T28T part1 complete
